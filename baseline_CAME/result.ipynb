# %% [markdown]
# # Result of CAME
# paper link: https://ieeexplore.ieee.org/abstract/document/10394558

# %% [markdown]
# ### ISIC2018 dataset

# %%
# %run test.py --batch_size 32 --test_data_path "../test_set" --model_path "model_weight/CAME-ISIC2018.pth"
# Out:
# using cuda:0 device.
# Namespace(batch_size=32, test_data_path='../test_set', model_path='model_weight/CAME-ISIC2018.pth')
# ['AKIEC', 'BCC', 'BKL', 'DF', 'MEL', 'NV', 'VASC']
# 3001 images for test.
# Using 8 dataloader workers every process
# [testing...]: 100%|██████████| 94/94 [00:28<00:00,  3.26it/s]
#               precision    recall  f1-score   support
#
#        AKIEC     0.5812    0.6939    0.6326        98
#          BCC     0.6959    0.6688    0.6821       154
#          BKL     0.6871    0.6809    0.6840       329
#           DF     0.7812    0.7353    0.7576        34
#          MEL     0.6508    0.6156    0.6327       333
#           NV     0.9227    0.9259    0.9243      2011
#         VASC     0.8667    0.9286    0.8966        42
#
#     accuracy                         0.8417      3001
#    macro avg     0.7408    0.7498    0.7443      3001
# weighted avg     0.8415    0.8417    0.8414      3001

# %% [markdown]
# ### Kvasir dataset

# %%
# fold 1
# %run test.py --batch_size 32 --test_data_path "../test_set_2" --model_path "model_weight/CAME-Kvasir-fold1.pth"
# Out:
# using cuda:0 device.
# Namespace(batch_size=32, test_data_path='../test_set_2', model_path='model_weight/CAME-Kvasir-fold1.pth')
# ['dyed-lifted-polyps', 'dyed-resection-margins', 'esophagitis', 'normal-cecum', 'normal-pylorus', 'normal-z-line', 'polyps', 'ulcerative-colitis']
# 2000 images for test.
# Using 8 dataloader workers every process
# [testing...]: 100%|██████████| 63/63 [00:20<00:00,  3.12it/s]
#                         precision    recall  f1-score   support
#
#     dyed-lifted-polyps     0.7717    0.7840    0.7778       250
# dyed-resection-margins     0.7840    0.7840    0.7840       250
#            esophagitis     0.8145    0.8080    0.8112       250
#           normal-cecum     0.9370    0.8920    0.9139       250
#         normal-pylorus     0.9394    0.9920    0.9650       250
#          normal-z-line     0.8135    0.8200    0.8167       250
#                 polyps     0.8099    0.8520    0.8304       250
# ...

# %%
# fold 2
# %run test.py --batch_size 32 --test_data_path "../training_set_2" --model_path "model_weight/CAME-Kvasir-fold2.pth"
# Out:
# using cuda:0 device.
# Namespace(batch_size=32, test_data_path='../training_set_2', model_path='model_weight/CAME-Kvasir-fold2.pth')
# ['dyed-lifted-polyps', 'dyed-resection-margins', 'esophagitis', 'normal-cecum', 'normal-pylorus', 'normal-z-line', 'polyps', 'ulcerative-colitis']
# 2000 images for test.
# Using 8 dataloader workers every process
# [testing...]: 100%|██████████| 63/63 [00:20<00:00,  3.11it/s]
#                         precision    recall  f1-score   support
#
#     dyed-lifted-polyps     0.7717    0.7840    0.7778       250
# dyed-resection-margins     0.7791    0.7760    0.7776       250
#            esophagitis     0.8658    0.8000    0.8316       250
#           normal-cecum     0.9228    0.9560    0.9391       250
#         normal-pylorus     0.9758    0.9680    0.9719       250
#          normal-z-line     0.8088    0.8800    0.8429       250
#                 polyps     0.8708    0.8360    0.8531       250
# ...

# %%
            # precision    recall  f1-score
# fold1
# accuracy                          0.8500
# macro avg     0.8512    0.8500    0.8502

# fold2
# accuracy                          0.8635 
# macro avg     0.8642    0.8635    0.8634
print('2-fold cross-validation result:')
print('accuracy: ', ((0.8635 + 0.8500) / 2))
print('precision: ', ((0.8642 + 0.8512) / 2))
print('recall: ', ((0.8635 + 0.8500) / 2))
print('f1-score: ', ((0.8634 + 0.8502) / 2))
# Out:
# 2-fold cross-validation result:
# accuracy:  0.85675
# precision:  0.8576999999999999
# recall:  0.85675
# f1-score:  0.8568

# %% [markdown]
# ### COVID19-CT dataset

# %%
# %run test.py --batch_size 32 --test_data_path "../test_set_3" --model_path "model_weight/CAME-COVID19-CT.pth"
# Out:
# using cuda:0 device.
# Namespace(batch_size=32, test_data_path='../test_set_3', model_path='model_weight/CAME-COVID19-CT.pth')
# ['CT_COVID', 'CT_NonCOVID']
# 186 images for test.
# Using 8 dataloader workers every process
# [testing...]: 100%|██████████| 6/6 [00:03<00:00,  1.60it/s]
#               precision    recall  f1-score   support
#
#     CT_COVID     0.7527    0.8046    0.7778        87
#  CT_NonCOVID     0.8172    0.7677    0.7917        99
#
#     accuracy                         0.7849       186
#    macro avg     0.7849    0.7861    0.7847       186
# weighted avg     0.7870    0.7849    0.7852       186
